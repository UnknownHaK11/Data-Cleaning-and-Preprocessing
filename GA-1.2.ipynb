# %%
import pandas as pd
import numpy as np

# %%
v5 = pd.read_csv('/content/V5.csv')

# %%
df = v5.copy()

# %%
df2 = df.iloc[::2]
df2.iloc[0,3]
# Out:
# 111440.0

# %%
df2.iloc[332,3]
# Out:
# 256200.0

# %%
df3 = df.iloc[1::2]
df3.iloc[332,3]
# Out:
# 352940.0

# %%
df4 = df.iloc[:, 1::2]
df4.iloc[100,5]
# Out:
# 'West'

# %%
df1 = df.iloc[::2, ::2]
df1.iloc[255, 3]
# Out:
# 'Detached House'

# %%
recent = df['Year'].max()
last_six = recent - 6
last_six
# Out:
# 2016

# %%
df['Year'].loc[df.Year > last_six].count()
# Out:
# 4749

# %%
df.loc[(df.num_rooms == 3) & (df.num_bathrooms == 3)].count()
# Out:
# Date                 2730
# Year                 2730
# Locality             2393
# Estimated Value      2374
# Sale Price           2730
# Property             2730
# Residential          2730
# num_rooms            2730
# num_bathrooms        2730
# carpet_area          2386
# property_tax_rate    2730
# Face                 2730
# dtype: int64

# %%
df.loc[(df.num_rooms == 3) | (df.num_bathrooms == 3)].count()
# Out:
# Date                 8591
# Year                 8591
# Locality             7528
# Estimated Value      7528
# Sale Price           8591
# Property             8591
# Residential          8591
# num_rooms            8591
# num_bathrooms        8591
# carpet_area          7524
# property_tax_rate    8591
# Face                 8591
# dtype: int64

# %%
condition = (df.num_rooms == 3) & (df.Locality == 'Greenwich') & (df.Year == 2022) & ((df.Face == 'North')| (df.Face == 'East'))

# %%
df.loc[condition].count()
# Out:
# Date                 42
# Year                 42
# Locality             42
# Estimated Value      32
# Sale Price           42
# Property             42
# Residential          42
# num_rooms            42
# num_bathrooms        42
# carpet_area          37
# property_tax_rate    42
# Face                 42
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date  Year    Locality  Estimated Value  Sale Price       Property  \
# 0 2009-01-02  2009   Waterbury         111440.0    185000.0  Single Family
# 1 2009-01-02  2009  Bridgeport         124670.0    150000.0     Two Family
# 2 2009-01-02  2009   Waterbury          55720.0    140000.0  Single Family
# 3 2009-01-02  2009  Bridgeport        4775276.0    272900.0  Single Family
# 4 2009-01-02  2009  Bridgeport         112351.0    210000.0              ?
#
#       Residential  num_rooms  num_bathrooms  carpet_area  property_tax_rate  \
# 0  Detached House          3              3        996.0           1.025953
# 1          Duplex          4              3       1241.0           1.025953
# 2  Detached House          3              2        910.0           1.025953
# 3  Detached House          3              1        971.0           1.025953
# 4  Detached House          3              2       1092.0           1.025953
#
#     Face
# 0  South
# 1  South
# 2  South
# 3   East
# ...

# %%
df['Month'] = df['Date'].dt.month

# %%
df.head(20)
# Out:
#          Date  Year    Locality  Estimated Value  Sale Price       Property  \
# 0  2009-01-02  2009   Waterbury         111440.0    185000.0  Single Family
# 1  2009-01-02  2009  Bridgeport         124670.0    150000.0     Two Family
# 2  2009-01-02  2009   Waterbury          55720.0    140000.0  Single Family
# 3  2009-01-02  2009  Bridgeport        4775276.0    272900.0  Single Family
# 4  2009-01-02  2009  Bridgeport         112351.0    210000.0              ?
# 5  2009-01-02  2009   Greenwich        2868880.0   3300000.0  Single Family
# 6  2009-01-02  2009     Norwalk         571060.0   1000000.0  Single Family
# 7  2009-01-02  2009   Greenwich         592760.0    920000.0  Single Family
# 8  2009-01-02  2009         NaN         603540.0   1680000.0  Single Family
# 9  2009-01-02  2009  Bridgeport         137901.0    245000.0  Single Family
# 10 2009-01-03  2009  Bridgeport         122150.0    256500.0  Single Family
# ...

# %%
df.loc[df.Month == 8].count()
# Out:
# Date                 1050
# Year                 1050
# Locality              925
# Estimated Value       920
# Sale Price           1050
# Property             1050
# Residential          1050
# num_rooms            1050
# num_bathrooms        1050
# carpet_area           915
# property_tax_rate    1050
# Face                 1050
# Month                1050
# dtype: int64

# %%
df_new = df.groupby('Locality')['Sale Price'].mean()
print(df_new.idxmax(),
df_new.max())
# Out:
# Greenwich 2270223.539495238
